# %%
import os
import bs4
from bs4 import BeautifulSoup
import requests
import pandas as pd
from datetime import datetime
from config import site_link

# %%
class Weather:
    def _city_temp_extractor(self,elem):
        temp = elem[len(elem)-3:-1]
        if temp[0] == '0':
            temp = temp[1]
        city =""
        for ele in elem:
            if ele.isalpha() or ele == ' ':
                city+=ele
            else:
                break
        city = city[:-1]
        return [city,temp,str(datetime.now())] 
    
    def saveToExcel(self):
        lis = self.worldWideReport()
        df = pd.DataFrame(data = lis,columns = ['City','Temparature-in-Celcius','Extraction-Datetime'])
        df.to_csv('weather.csv')
        print(f"Data saved in {os.getcwd()}\\weather.csv")
        
    def worldWideReport(self):
        url= site_link['url']
        page = requests.get(url)
        print(page)
        soup =  BeautifulSoup(page.content,'html.parser')
        #print(soup.prettify())
        table = soup.find_all('tr')
        #print(table)
        unfiltered_weather_list1 = []
        unfiltered_weather_list2 = []
        final_weather_list = []
        for i in range(len(table)):
            if i == 0:
                continue
            text = table[i].getText()
            weather_text = text.split('°C')
            #print(weather_text)
            unfiltered_weather_list1.append(weather_text[0])
            unfiltered_weather_list2.append(weather_text[1])
            
        for elem in unfiltered_weather_list1:
            final_weather_list.append(self._city_temp_extractor(elem))
        for elem in unfiltered_weather_list2:
            final_weather_list.append(self._city_temp_extractor(elem)) 

        return final_weather_list

# %%
weather = Weather()
weather.worldWideReport()
# Out:
# <Response [200]>
# [['Accra', '27', '2023-08-03 21:42:58.886292'],
#  ['Addis Ababa', '16', '2023-08-03 21:42:58.886292'],
#  ['Adelaide', '22', '2023-08-03 21:42:58.886292'],
#  ['Algiers', '33', '2023-08-03 21:42:58.886292'],
#  ['Almaty', '28', '2023-08-03 21:42:58.886292'],
#  ['Amman', '32', '2023-08-03 21:42:58.886292'],
#  ['Amsterdam', '16', '2023-08-03 21:42:58.886292'],
#  ['Anadyr', '12', '2023-08-03 21:42:58.886292'],
#  ['Anchorage', '13', '2023-08-03 21:42:58.886292'],
#  ['Ankara', '35', '2023-08-03 21:42:58.886292'],
#  ['Antananarivo', '16', '2023-08-03 21:42:58.886292'],
#  ['Asuncion', '30', '2023-08-03 21:42:58.886292'],
#  ['Athens', '32', '2023-08-03 21:42:58.886292'],
#  ['Atlanta', '25', '2023-08-03 21:42:58.886292'],
#  ['Auckland', '25', '2023-08-03 21:42:58.886292'],
#  ['Bangkok', '27', '2023-08-03 21:42:58.886292'],
#  ['Barcelona', '26', '2023-08-03 21:42:58.886292'],
#  ['Beijing', '30', '2023-08-03 21:42:58.886292'],
#  ['Beirut', '30', '2023-08-03 21:42:58.886292'],
#  ['Belgrade', '35', '2023-08-03 21:42:58.886292'],
#  ['Bengaluru', '24', '2023-08-03 21:42:58.886292'],
#  ['Berlin', '20', '2023-08-03 21:42:58.886292'],
#  ['Bogota', '17', '2023-08-03 21:42:58.887293'],
#  ['Boston', '24', '2023-08-03 21:42:58.887293'],
#  ['Brasilia', '26', '2023-08-03 21:42:58.887293'],
#  ['Brisbane', '14', '2023-08-03 21:42:58.887293'],
#  ['Brussels', '16', '2023-08-03 21:42:58.887293'],
#  ['Bucharest', '36', '2023-08-03 21:42:58.887293'],
#  ['Budapest', '28', '2023-08-03 21:42:58.887293'],
#  ['Buenos Aires', '11', '2023-08-03 21:42:58.887293'],
#  ['Cairo', '34', '2023-08-03 21:42:58.887293'],
#  ['Calgary', '16', '2023-08-03 21:42:58.887293'],
#  ['Canberra', '22', '2023-08-03 21:42:58.887293'],
#  ['Cape Town', '25', '2023-08-03 21:42:58.887293'],
#  ['Caracas', '31', '2023-08-03 21:42:58.887293'],
#  ['Casablanca', '24', '2023-08-03 21:42:58.887293'],
#  ['Chicago', '26', '2023-08-03 21:42:58.887293'],
#  ['Copenhagen', '18', '2023-08-03 21:42:58.887293'],
#  ['Dallas', '32', '2023-08-03 21:42:58.887293'],
#  ['Dar es Salaam', '26', '2023-08-03 21:42:58.887293'],
#  ['Darwin', '23', '2023-08-03 21:42:58.887293'],
#  ['Denver', '21', '2023-08-03 21:42:58.887293'],
#  ['Detroit', '27', '2023-08-03 21:42:58.887293'],
#  ['Dhaka', '29', '2023-08-03 21:42:58.887293'],
#  ['Doha', '37', '2023-08-03 21:42:58.887293'],
#  ['Dubai', '41', '2023-08-03 21:42:58.887293'],
#  ['Dublin', '19', '2023-08-03 21:42:58.887293'],
#  ['Edmonton', '16', '2023-08-03 21:42:58.887293'],
#  ['Frankfurt', '21', '2023-08-03 21:42:58.887293'],
#  ['Guatemala City', '22', '2023-08-03 21:42:58.887293'],
#  ['Halifax', '23', '2023-08-03 21:42:58.887293'],
#  ['Hanoi', '28', '2023-08-03 21:42:58.887293'],
#  ['Harare', '18', '2023-08-03 21:42:58.887293'],
#  ['Havana', '33', '2023-08-03 21:42:58.887293'],
#  ['Helsinki', '18', '2023-08-03 21:42:58.887293'],
#  ['Hong Kong', '31', '2023-08-03 21:42:58.887293'],
#  ['Honolulu', '25', '2023-08-03 21:42:58.887293'],
#  ['Houston', '32', '2023-08-03 21:42:58.887293'],
#  ['Indianapolis', '26', '2023-08-03 21:42:58.887293'],
#  ['Islamabad', '32', '2023-08-03 21:42:58.887293'],
#  ['Istanbul', '34', '2023-08-03 21:42:58.887293'],
#  ['Jakarta', '29', '2023-08-03 21:42:58.887293'],
#  ['Jerusalem', '27', '2023-08-03 21:42:58.887293'],
#  ['Johannesburg', '14', '2023-08-03 21:42:58.887293'],
#  ['Karachi', '29', '2023-08-03 21:42:58.887293'],
#  ['Kathmandu', '23', '2023-08-03 21:42:58.887293'],
#  ['Kingston', '32', '2023-08-03 21:42:58.887293'],
#  ['Kinshasa', '28', '2023-08-03 21:42:58.887293'],
#  ['Kiritimati', '27', '2023-08-03 21:42:58.887293'],
#  ['Kolkata', '30', '2023-08-03 21:42:58.887293'],
#  ['Kuala Lumpur', '29', '2023-08-03 21:42:58.887293'],
#  ['Kuwait City', '46', '2023-08-03 21:42:58.887293'],
#  ['Kyiv', '27', '2023-08-03 21:42:58.887293'],
#  ['La Paz', '11', '2023-08-03 21:42:58.887293'],
#  ['Lagos', '28', '2023-08-03 21:42:58.887293'],
#  ['Lahore', '34', '2023-08-03 21:42:58.887293'],
#  ['Las Vegas', '27', '2023-08-03 21:42:58.887293'],
#  ['Lima', '20', '2023-08-03 21:42:58.887293'],
#  ['Lisbon', '24', '2023-08-03 21:42:58.887293'],
#  ['London', '20', '2023-08-03 21:42:58.887293'],
#  ['Los Angeles', '22', '2023-08-03 21:42:58.887293'],
#  ['Madrid', '31', '2023-08-03 21:42:58.887293'],
#  ['Managua', '31', '2023-08-03 21:42:58.887293'],
#  ['Manila', '28', '2023-08-03 21:42:58.887293'],
#  ['Melbourne', '14', '2023-08-03 21:42:58.887293'],
#  ['Mexico City', '18', '2023-08-03 21:42:58.887293'],
#  ['Miami', '30', '2023-08-03 21:42:58.887293'],
#  ['Minneapolis', '23', '2023-08-03 21:42:58.887293'],
#  ['Minsk', '26', '2023-08-03 21:42:58.887293'],
#  ['Montevideo', '12', '2023-08-03 21:42:58.887293'],
#  ['Montréal', '21', '2023-08-03 21:42:58.887293'],
#  ['Moscow', '27', '2023-08-03 21:42:58.887293'],
#  ['Mumbai', '28', '2023-08-03 21:42:58.887293'],
#  ['Nairobi', '18', '2023-08-03 21:42:58.887293'],
#  ['Nassau', '31', '2023-08-03 21:42:58.887293'],
#  ['New Delhi', '31', '2023-08-03 21:42:58.887293'],
#  ['New Orleans', '33', '2023-08-03 21:42:58.887293'],
#  ['New York', '24', '2023-08-03 21:42:58.887293'],
#  ['Oslo', '21', '2023-08-03 21:42:58.887293'],
#  ['Ottawa', '22', '2023-08-03 21:42:58.887293'],
#  ['Paris', '16', '2023-08-03 21:42:58.887293'],
#  ['Perth', '25', '2023-08-03 21:42:58.887293'],
#  ['Philadelphia', '25', '2023-08-03 21:42:58.887293'],
#  ['Phoenix', '36', '2023-08-03 21:42:58.887293'],
#  ['Prague', '24', '2023-08-03 21:42:58.887293'],
#  ['Reykjavik', '13', '2023-08-03 21:42:58.887293'],
#  ['Rio de Janeiro', '25', '2023-08-03 21:42:58.887293'],
#  ['Riyadh', '44', '2023-08-03 21:42:58.887293'],
#  ['Rome', '32', '2023-08-03 21:42:58.887293'],
#  ['Salt Lake City', '18', '2023-08-03 21:42:58.887293'],
#  ['San Francisco', '16', '2023-08-03 21:42:58.887293'],
#  ['San Juan', '31', '2023-08-03 21:42:58.887293'],
#  ['San Salvador', '26', '2023-08-03 21:42:58.887293'],
#  ['Santiago', '15', '2023-08-03 21:42:58.887293'],
#  ['Santo Domingo', '32', '2023-08-03 21:42:58.887293'],
#  ['São Paulo', '26', '2023-08-03 21:42:58.887293'],
#  ['Seattle', '19', '2023-08-03 21:42:58.887293'],
#  ['Seoul', '26', '2023-08-03 21:42:58.887293'],
#  ['Shanghai', '29', '2023-08-03 21:42:58.887293'],
#  ['Singapore', '26', '2023-08-03 21:42:58.887293'],
#  ['Sofia', '33', '2023-08-03 21:42:58.887293'],
#  ['S', '21', '2023-08-03 21:42:58.887293'],
#  ['Stockholm', '18', '2023-08-03 21:42:58.887293'],
#  ['Suva', '22', '2023-08-03 21:42:58.887293'],
#  ['Sydney', '13', '2023-08-03 21:42:58.887293'],
#  ['Taipei', '29', '2023-08-03 21:42:58.887293'],
#  ['Tallinn', '17', '2023-08-03 21:42:58.887293'],
#  ['Tashkent', '35', '2023-08-03 21:42:58.887293'],
#  ['Tegucigalpa', '24', '2023-08-03 21:42:58.887293'],
#  ['Tehran', '38', '2023-08-03 21:42:58.887293'],
#  ['Tokyo', '28', '2023-08-03 21:42:58.887293'],
#  ['Toronto', '26', '2023-08-03 21:42:58.887293'],
#  ['Vancouver', '19', '2023-08-03 21:42:58.887293'],
#  ['Vienna', '20', '2023-08-03 21:42:58.887293'],
#  ['Warsaw', '21', '2023-08-03 21:42:58.887293'],
#  ['Washington DC', '24', '2023-08-03 21:42:58.887293'],
#  ['Winnipeg', '23', '2023-08-03 21:42:58.887293'],
#  ['Yangon', '28', '2023-08-03 21:42:58.887293'],
#  ['Zagreb', '28', '2023-08-03 21:42:58.887293'],
#  ['Zürich', '24', '2023-08-03 21:42:58.887293']]

# %%
weather.saveToExcel()
# Out:
# <Response [200]>
# Data saved in C:\Users\bibha\Desktop\Weather-for-git\weather.csv

# %%
# !pip install twine
# Out:
# Collecting twine
#   Downloading twine-4.0.2-py3-none-any.whl (36 kB)
# Requirement already satisfied: keyring>=15.1 in c:\users\bibha\anaconda3\envs\rtds\lib\site-packages (from twine) (23.13.1)
# Requirement already satisfied: urllib3>=1.26.0 in c:\users\bibha\anaconda3\envs\rtds\lib\site-packages (from twine) (1.26.15)
# Requirement already satisfied: requests>=2.20 in c:\users\bibha\anaconda3\envs\rtds\lib\site-packages (from twine) (2.29.0)
# Collecting rich>=12.0.0
#   Downloading rich-13.5.2-py3-none-any.whl (239 kB)
#      ---------------------------------------- 0.0/239.7 kB ? eta -:--:--
#      --------- ----------------------------- 61.4/239.7 kB 3.2 MB/s eta 0:00:01
#      ------------------------------ ------- 194.6/239.7 kB 2.4 MB/s eta 0:00:01
#      -------------------------------------- 239.7/239.7 kB 1.8 MB/s eta 0:00:00
# Collecting pkginfo>=1.8.1
#   Downloading pkginfo-1.9.6-py3-none-any.whl (30 kB)
# Collecting readme-renderer>=35.0
#   Downloading readme_renderer-40.0-py3-none-any.whl (14 kB)
# Requirement already satisfied: importlib-metadata>=3.6 in c:\users\bibha\anaconda3\envs\rtds\lib\site-packages (from twine) (6.0.0)
# Collecting requests-toolbelt!=0.9.0,>=0.8.0
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
#      ---------------------------------------- 0.0/54.5 kB ? eta -:--:--
#      ---------------------------------------- 54.5/54.5 kB ? eta 0:00:00
# Collecting rfc3986>=1.4.0
#   Downloading rfc3986-2.0.0-py2.py3-none-any.whl (31 kB)
# Requirement already satisfied: zipp>=0.5 in c:\users\bibha\anaconda3\envs\rtds\lib\site-packages (from importlib-metadata>=3.6->twine) (3.11.0)
# Requirement already satisfied: jaraco.classes in c:\users\bibha\anaconda3\envs\rtds\lib\site-packages (from keyring>=15.1->twine) (3.2.1)
# Requirement already satisfied: pywin32-ctypes>=0.2.0 in c:\users\bibha\anaconda3\envs\rtds\lib\site-packages (from keyring>=15.1->twine) (0.2.0)
# Requirement already satisfied: bleach>=2.1.0 in c:\users\bibha\anaconda3\envs\rtds\lib\site-packages (from readme-renderer>=35.0->twine) (4.1.0)
# Requirement already satisfied: docutils>=0.13.1 in c:\users\bibha\anaconda3\envs\rtds\lib\site-packages (from readme-renderer>=35.0->twine) (0.18.1)
# Requirement already satisfied: Pygments>=2.5.1 in c:\users\bibha\anaconda3\envs\rtds\lib\site-packages (from readme-renderer>=35.0->twine) (2.15.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\bibha\anaconda3\envs\rtds\lib\site-packages (from requests>=2.20->twine) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\bibha\anaconda3\envs\rtds\lib\site-packages (from requests>=2.20->twine) (2023.5.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\bibha\anaconda3\envs\rtds\lib\site-packages (from requests>=2.20->twine) (2.0.4)
# Collecting markdown-it-py>=2.2.0
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
#      ---------------------------------------- 0.0/87.5 kB ? eta -:--:--
#      ---------------------------------------- 87.5/87.5 kB ? eta 0:00:00
# Requirement already satisfied: webencodings in c:\users\bibha\anaconda3\envs\rtds\lib\site-packages (from bleach>=2.1.0->readme-renderer>=35.0->twine) (0.5.1)
# Requirement already satisfied: six>=1.9.0 in c:\users\bibha\anaconda3\envs\rtds\lib\site-packages (from bleach>=2.1.0->readme-renderer>=35.0->twine) (1.16.0)
# Requirement already satisfied: packaging in c:\users\bibha\anaconda3\envs\rtds\lib\site-packages (from bleach>=2.1.0->readme-renderer>=35.0->twine) (23.0)
# Collecting mdurl~=0.1
#   Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Requirement already satisfied: more-itertools in c:\users\bibha\anaconda3\envs\rtds\lib\site-packages (from jaraco.classes->keyring>=15.1->twine) (8.12.0)
# Installing collected packages: rfc3986, pkginfo, mdurl, requests-toolbelt, readme-renderer, markdown-it-py, rich, twine
# Successfully installed markdown-it-py-3.0.0 mdurl-0.1.2 pkginfo-1.9.6 readme-renderer-40.0 requests-toolbelt-1.0.0 rfc3986-2.0.0 rich-13.5.2 twine-4.0.2
# WARNING: Ignoring invalid distribution -upyterlab (c:\users\bibha\anaconda3\envs\rtds\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\bibha\anaconda3\envs\rtds\lib\site-packages)
# WARNING: Ignoring invalid distribution -upyterlab (c:\users\bibha\anaconda3\envs\rtds\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\bibha\anaconda3\envs\rtds\lib\site-packages)
# WARNING: Ignoring invalid distribution -upyterlab (c:\users\bibha\anaconda3\envs\rtds\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\bibha\anaconda3\envs\rtds\lib\site-packages)
# WARNING: Ignoring invalid distribution -upyterlab (c:\users\bibha\anaconda3\envs\rtds\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\bibha\anaconda3\envs\rtds\lib\site-packages)
# WARNING: Ignoring invalid distribution -upyterlab (c:\users\bibha\anaconda3\envs\rtds\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\bibha\anaconda3\envs\rtds\lib\site-packages)
# WARNING: Ignoring invalid distribution -upyterlab (c:\users\bibha\anaconda3\envs\rtds\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\bibha\anaconda3\envs\rtds\lib\site-packages)
# WARNING: Ignoring invalid distribution -upyterlab (c:\users\bibha\anaconda3\envs\rtds\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\bibha\anaconda3\envs\rtds\lib\site-packages)
# WARNING: Ignoring invalid distribution -upyterlab (c:\users\bibha\anaconda3\envs\rtds\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\bibha\anaconda3\envs\rtds\lib\site-packages)
# WARNING: Ignoring invalid distribution -upyterlab (c:\users\bibha\anaconda3\envs\rtds\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\bibha\anaconda3\envs\rtds\lib\site-packages)
# WARNING: Ignoring invalid distribution -upyterlab (c:\users\bibha\anaconda3\envs\rtds\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\bibha\anaconda3\envs\rtds\lib\site-packages)
# WARNING: Ignoring invalid distribution -upyterlab (c:\users\bibha\anaconda3\envs\rtds\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\bibha\anaconda3\envs\rtds\lib\site-packages)
# WARNING: Ignoring invalid distribution -upyterlab (c:\users\bibha\anaconda3\envs\rtds\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\bibha\anaconda3\envs\rtds\lib\site-packages)
# WARNING: Ignoring invalid distribution -upyterlab (c:\users\bibha\anaconda3\envs\rtds\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\bibha\anaconda3\envs\rtds\lib\site-packages)
# WARNING: Ignoring invalid distribution -upyterlab (c:\users\bibha\anaconda3\envs\rtds\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\bibha\anaconda3\envs\rtds\lib\site-packages)
#
# [notice] A new release of pip is available: 23.1.2 -> 23.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
